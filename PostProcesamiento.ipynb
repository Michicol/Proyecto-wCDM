# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#/content/drive/MyDrive/Proyecto LCDM 2/Proyecto LCDM
df = pd.read_csv('./DatosCadenaDeMarkov.csv')
#df.drop('Unnamed: 0')
df.columns
# Out:
# Index(['Unnamed: 0', 'Omo', 'Ol', 'H0', 'like'], dtype='object')

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#         Omo        Ol         H0        like
# 0  0.282712  0.717203  69.705205 -271.456836
# 1  0.275841  0.724074  69.741142 -271.465256
# 2  0.296773  0.703142  70.005910 -273.009473
# 3  0.284715  0.715200  69.791510 -271.370540
# 4  0.270276  0.729639  69.975149 -271.142415

# %%
hue = df['like']

# %%
sns.pairplot(df[['Omo','Ol','H0']])
